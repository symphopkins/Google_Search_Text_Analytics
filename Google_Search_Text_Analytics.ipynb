# %% [markdown]
# # DSCI 614: Project 1
#
# ### Symphony Hopkins

# %% [markdown]
# ## Introduction
#
# We are part of a data scientist team working for the Department of Transportation. We have built a road condition dashboard. Our manager wants us to have more search data. Our manager lets us monitor the Google Search feeds and get the latest 100 searches regarding the weather. We are asked to perform the following tasks.

# %% [markdown]
# ## Step 1: Search Google using the keywords "Winter snowstorm". (Please use the sample codes in the attached workbook Google Search extract info (1).ipynb
#
# We will begin by importing the necessary libraries.

# %%
# importing libraries
from googlesearch import search
import pandas as pd

# %% [markdown]
# Now, we will provide the arugments for the search function. We want to use "Winter snowstorm" as the query. We also want to return 100 results, including the URL, title, and description.

# %%
#providing the query for the search
query = "Winter snowstorm"

#returning 100 results, including the URL, title, and description 
results = list(search(query, num_results=99, sleep_interval=5, lang="en",advanced=True))

#printing results
print(results)
# Out:
# [SearchResult(url=https://www.weather.gov/safety/winter-during, title=What To Do If You're Caught in a Winter Storm, description=When caught in a winter storm, there are life-saving actions you can take to protect yourself outside, in a vehicle and inside your home or office. +Outside.), SearchResult(url=https://www.weather.gov/safety/winter-snow, title=Snow Storm Safety, description=Blizzard: Sustained winds or frequent gusts of 35 mph or more with snow and blowing snow frequently reducing visibility to less than a quarter mile for 3 hours ...), SearchResult(url=https://www.nssl.noaa.gov/education/svrwx101/winter/types/, title=Severe Weather 101: Winter Weather Types, description=A winter storm is a combination of heavy snow, blowing snow and/or dangerous wind chills. A winter storm is life-threatening. Blizzards are dangerous winter ...), SearchResult(url=https://en.wikipedia.org/wiki/Winter_storm, title=Winter storm, description=A winter storm is an event in which wind coincides with varieties of precipitation that only occur at freezing temperatures, such as snow, mixed snow and ...), SearchResult(url=https://scied.ucar.edu/learning-zone/storms/winter-storms, title=Winter Storms - UCAR Center for Science Education, description=Snowstorms are one type of winter storm. Blizzards are snowstorms with high winds, and lake effect storms are snowstorms that form near the Great Lakes.), SearchResult(url=https://www.cdc.gov/disasters/winter/beforestorm/preparehome.html, title=Preparing for a Winter Storm|Winter Weather, description=Winter storms can bring cold temperatures, power failures, loss of communication services, and icy roads. To keep yourself and your loved ones safe, ...), SearchResult(url=https://www.redcross.org/get-help/how-to-prepare-for-emergencies/types-of-emergencies/winter-storm.html, title=Winter Storm Preparedness & Blizzard Safety, description=Winter storms can bring extreme cold, freezing rain, sleet, heavy snowfall, ice, and high winds. These storms can cause transportation, heat, power, ...), SearchResult(url=https://weather.com/storms/winter, title=Winter Storm, description=As Winter Storm Olive moved through Michigan knocking down trees, one Ann Arbor ... These Eagle Parents Had An Important Task, Even During A Snowstorm.), SearchResult(url=https://www.mass.gov/info-details/winter-storm-safety-tips, title=Winter Storm Safety Tips, description=Winter storms in New England can range from freezing rain and ice, to a moderate snowfall over a few hours, to blizzard conditions with blinding wind-driven ...), SearchResult(url=https://www.ready.gov/winter-weather, title=Winter Weather, description=Nov 29, 2022 — Winter storms including blizzards can bring extreme cold, freezing rain, snow, ice and high winds. A winter storm can: feature_mini img. Last a ...), SearchResult(url=https://www.nytimes.com/2023/03/13/us/winter-storm-noreaster-snow-forecast.html, title=Late-Winter Storm Brings Heavy Snow and Rain to the ..., description=Mar 15, 2023 — A major storm dropped more than two feet of snow in portions of northwest Massachusetts and southern Vermont, while some cities only saw ...), SearchResult(url=https://www.npr.org/2023/02/21/1158546553/winter-storm-heavy-snow-22-states, title=A huge winter storm is expected to affect millions across 22 ..., description=Feb 21, 2023 — Residents in 22 states are under winter weather alerts this week with a huge storm expected to bring heavy snow and high winds, the National ...), SearchResult(url=https://www.usatoday.com/story/news/nation/2022/12/19/winter-storm-forecast-christmas-weather-travel/10924147002/, title='Big mess' is days away: Major winter storm to bring snow ..., description=Dec 19, 2022 — Bitterly cold temperatures and a significant winter snowstorm could threaten holiday travel plans for millions across the U.S. from the ...), SearchResult(url=https://www.cnn.com/2023/02/21/weather/winter-storm-us-tuesday/index.html, title=Winter storm set to impact millions s ...

# %% [markdown]
# ## Step 2: Extract the latest 100 results, including the URL, title, and description.

# %% [markdown]
# Before we can extract the information, we need to convert the SearchResult objects to a list of strings.

# %%
results = [str(item) for item in results]

# %% [markdown]
# Now, we can create a for loop and extract the information from the results. After extracting the URL, title, and description from each result, we will store it in a dictionary.

# %%
data =[]
for result in results:
    #extracting the URL, title, and description using string manipulation
    url = result.split("url=")[1].split(",")[0]
    title = result.split("title=")[1].split(",")[0]
    description = result.split("description=")[1].split(")")[0]
    
    #creating a dictionary for each SearchResult
    result_dict = {
        'URL': url,
        'Title': title,
        'Description': description
    }
    
    #appending the dictionary to the data list
    data.append(result_dict)

# %% [markdown]
# ## Step 3: Save the results in a data frame with columns of the URL, title, and description.

# %% [markdown]
# Now, we will save the results in a dataframe, and display the first 5 rows.

# %%
#creating the dataframe
df = pd.DataFrame(data)
df.head(5)
# Out:
#                                                  URL  \
# 0       https://www.weather.gov/safety/winter-during
# 1         https://www.weather.gov/safety/winter-snow
# 2  https://www.nssl.noaa.gov/education/svrwx101/w...
# 3         https://en.wikipedia.org/wiki/Winter_storm
# 4  https://scied.ucar.edu/learning-zone/storms/wi...
#
#                                                Title  \
# 0      What To Do If You're Caught in a Winter Storm
# 1                                  Snow Storm Safety
# 2           Severe Weather 101: Winter Weather Types
# 3                                       Winter storm
# 4  Winter Storms - UCAR Center for Science Education
#
#                                          Description
# 0  When caught in a winter storm, there are life-...
# 1  Blizzard: Sustained winds or frequent gusts of...
# 2  A winter storm is a combination of heavy snow,...
# 3  A winter storm is an event in which wind coinc...
# 4  Snowstorms are one type of winter storm. Blizz...

# %%
df['Description'].to_string()
# Out:
# "0      When caught in a winter storm, there are life-...\n1      Blizzard: Sustained winds or frequent gusts of...\n2      A winter storm is a combination of heavy snow,...\n3      A winter storm is an event in which wind coinc...\n4      Snowstorms are one type of winter storm. Blizz...\n5      Winter storms can bring cold temperatures, pow...\n6      Winter storms can bring extreme cold, freezing...\n7      As Winter Storm Olive moved through Michigan k...\n8      Winter storms in New England can range from fr...\n9      Nov 29, 2022 — Winter storms including blizzar...\n10     Mar 15, 2023 — A major storm dropped more than...\n11     Feb 21, 2023 — Residents in 22 states are unde...\n12     Dec 19, 2022 — Bitterly cold temperatures and ...\n13     Feb 21, 2023 — A massive winter storm bringing...\n14     Mar 15, 2023 — With 4 to 6 inches of snow pred...\n15     Mar 3, 2023 — Our winter snowstorm across Sout...\n16     Dec 12, 2022 — A large winter storm slammed in...\n17     Feb 22, 2023 — In Minneapolis, residents are b...\n18     Feb 23, 2023 — The Twin Cities were forecast t...\n19     AccuWeather forecasters warn that a major wint...\n20     Dec 19, 2022 — According to the FOX Forecast C...\n21     You probably even have a memory of your own wo...\n22     Dec 17, 2020 — Northeast digs out after deadly...\n23     Dec 28, 2022 — A powerful winter storm that sl...\n24     Mid-Atlantic Winter Storm Patterns. Miller A t...\n25     Dec 27, 2022 — A general view of vehicles cove...\n26     Winter Snowstorm Wish. Winter Storm Wish. I kn...\n27     Mar 1, 2023 — Flagstaff was hit with several i...\n28     Jan 25, 2023 — — A winter storm that was forec...\n29     Back in the olden days, it was no small feat t...\n30     Historic winter snowstorm turns deadly in Oreg...\n31     Jan 16, 2023 — Fun and easy winter science act...\n32                            May 23, 2023 — DALLAS (SMU\n33     Feb 27, 2023 — Snow hit along out coastal comm...\n34     Jan 30, 2022 — Thousands of power outages were...\n35     Feb 22, 2023 — Pacific winter snowstorm this w...\n36     Mar 11, 2015 — There are plenty of places wher...\n37     Winter Snowstorm Project. First thing you need...\n38     Feb 19, 2023 — This is due to a pretty sizable...\n39     As Texas faced record-low temperatures in Febr...\n40     Jan 13, 2023 — We're halfway through meteorolo...\n41     Jan 13, 2021 — Winter snowstorm targets Minnes...\n42     Jan 15, 2022 — States of emergency declared in...\n43     Jan 6, 2023 — Though thunder and lightning in ...\n44     Feb 27, 2023 — Winter snowstorm CT: School clo...\n45     Mar 7, 2023 — Winter Weather Impacts for March...\n46     Nov 15, 2022 — It's not winter yet, but Midwes...\n47     Mar 13, 2023 — Late-winter snowstorm could be ...\n48     Feb 28, 2023 — Southern New Englanders take la...\n49     Mar 14, 2021 — A powerful late winter snowstor...\n50     Winter storms may include high wind, freezing ...\n51     Jan 17, 2019 — Street crews and law enforcemen...\n52     Feb 23, 2023 — Wyoming Slammed With Late Winte...\n53     Winter Storms. Before a Winter Storm. Weather ...\n54     Two smaller snowstorms followed the Blizzard a...\n55     Feb 27, 2023 — WALTHAM, MA – National Grid is ...\n56     NY-2023-04, March 24, 2023 — Victims of the se...\n57     Jan 22, 2016 — Keep Safe During a Major Winter...\n58     There he and Old Man Winter sit and smoke, and...\n59     Jan 29, 2023 — The snow from a winter storm ha...\n60     Jan 13, 2022 — A major winter storm will start...\n61     Dec 22, 2022 — Kansas saw a rare combination o...\n62     Dec 19, 2022 — As the first day of winter and ...\n63     Mar 8, 2023 — When Watertown, New York, Pharma...\n64     Download Winter Snowstorm stock photos. Free o...\n65     Early winter snowstorm wreaks havoc on Illinoi...\n66     Dec 23, 2022 — Winter storm brings snow, frigi...\n67     Below, we have listed the 25 largest snowfall ...\n68     May 23, 2023 — Natural disasters can wreak hav.. ...

# %% [markdown]
# ## Step 4: Create a word cloud for the text of these descriptions.

# %% [markdown]
# Next, we will create a word cloud to help visualize the most used words from the descriptions. We will start by importing the necessary libraries.

# %%
#importing libraries
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# %% [markdown]
# We can now create the word cloud.

# %%
#converting the Panda series to a string
words = df['Description'].to_string()

#creating a word cloud
wordcloud = WordCloud().generate(words)

#visualizing the word cloud
# %matplotlib inline
plt.figure(figsize=(12, 9))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()

# %% [markdown]
# As we can see, words like "winter storm", "Jan", "Feb", etc. were used frequently in the google searches.

# %% [markdown]
# ## Step 5: Perform the named entity recognition on the descriptions.

# %% [markdown]
# We also want to perform a Named Entity Recogntion (NER) to extract information like names, locations, and dates from the description words. We will begin by importing the necessary libraries.

# %%
import spacy
import en_core_web_sm

# %% [markdown]
# Next, we will use the pretrained statistical model, en_core_web_sm, to perform NER.

# %%
#loading the pretrained statistical models for English
nlp = en_core_web_sm.load()

#passing the words to the pretrained statistical model
doc = nlp(words)

#displaying all the NERs
if doc.ents: #if there are some entities, print them out
    for ent in doc.ents:
        print(f'{ent.text} : {ent.label_} - {spacy.explain(ent.label_)}')
else: # no name entities found
    print(f'I can not find any name entities!')
# Out:
# 1      Blizzard: : QUANTITY - Measurements, as of weight or distance
# 2       : QUANTITY - Measurements, as of weight or distance
# 3       : QUANTITY - Measurements, as of weight or distance
# 4 : CARDINAL - Numerals that do not fall under another type
# one : CARDINAL - Numerals that do not fall under another type
# 5 : CARDINAL - Numerals that do not fall under another type
# 6      Winter : QUANTITY - Measurements, as of weight or distance
# 7      As Winter Storm Olive : QUANTITY - Measurements, as of weight or distance
# Michigan : GPE - Countries, cities, states
# 8      Winter : QUANTITY - Measurements, as of weight or distance
# New England : LOC - Non-GPE locations, mountain ranges, bodies of water
# 9      Nov 29, 2022 : QUANTITY - Measurements, as of weight or distance
# 10 : CARDINAL - Numerals that do not fall under another type
# 15, 2023 : DATE - Absolute or relative dates or periods
# 11 : CARDINAL - Numerals that do not fall under another type
# 22 : CARDINAL - Numerals that do not fall under another type
# 12 : CARDINAL - Numerals that do not fall under another type
# 19, 2022 : DATE - Absolute or relative dates or periods
# 13 : CARDINAL - Numerals that do not fall under another type
# winter : DATE - Absolute or relative dates or periods
# 14 : CARDINAL - Numerals that do not fall under another type
# 15, 2023 : DATE - Absolute or relative dates or periods
# 4 to 6 inches : TIME - Times smaller than a day
# 15 : CARDINAL - Numerals that do not fall under another type
# 16 : CARDINAL - Numerals that do not fall under another type
# 12, 2022 : DATE - Absolute or relative dates or periods
# 17 : CARDINAL - Numerals that do not fall under another type
# Minneapolis : GPE - Countries, cities, states
# 18 : CARDINAL - Numerals that do not fall under another type
# 19 : CARDINAL - Numerals that do not fall under another type
# AccuWeather : ORG - Companies, agencies, institutions, etc.
# 20 : CARDINAL - Numerals that do not fall under another type
# 19, 2022 : DATE - Absolute or relative dates or periods
# 21 : CARDINAL - Numerals that do not fall under another type
# 22 : CARDINAL - Numerals that do not fall under another type
# Dec 17, 2020 : DATE - Absolute or relative dates or periods
# Northeast : LOC - Non-GPE locations, mountain ranges, bodies of water
# 23 : CARDINAL - Numerals that do not fall under another type
# 28, 2022 : DATE - Absolute or relative dates or periods
# winter : DATE - Absolute or relative dates or periods
# 24 : CARDINAL - Numerals that do not fall under another type
# Miller : PERSON - People, including fictional
# 25 : CARDINAL - Numerals that do not fall under another type
# 27, 2022 : DATE - Absolute or relative dates or periods
# 26 : CARDINAL - Numerals that do not fall under another type
# Winter Storm Wish : PERSON - People, including fictional
# 27 : CARDINAL - Numerals that do not fall under another type
# 28 : CARDINAL - Numerals that do not fall under another type
# Jan 25, 2023 : DATE - Absolute or relative dates or periods
# 29 : CARDINAL - Numerals that do not fall under another type
# the olden days : DATE - Absolute or relative dates or periods
# 30 : CARDINAL - Numerals that do not fall under another type
# Oreg : GPE - Countries, cities, states
# 31 : CARDINAL - Numerals that do not fall under another type
# Jan 16, 2023 : DATE - Absolute or relative dates or periods
# 32 : CARDINAL - Numerals that do not fall under another type
# May 23, 2023 : DATE - Absolute or relative dates or periods
# DALLAS : GPE - Countries, cities, states
# SMU : ORG - Companies, agencies, institutions, etc.
# 33 : CARDINAL - Numerals that do not fall under another type
# 34 : CARDINAL - Numerals that do not fall under another type
# Jan 30, 2022 : DATE - Absolute or relative dates or periods
# Thousands : CARDINAL - Numerals that do not fall under another type
# 35 : CARDINAL - Numerals that do not fall under another type
# 36 : CARDINAL - Numerals that do not fall under another type
# 11, 2015 : DATE - Absolute or relative dates or periods
# 37 : CARDINAL - Numerals that do not fall under another type
# First : ORDINAL - "first", "second", etc.
# 38 : CARDINAL - Numerals that do not fall under another type
# 39 : CARDINAL - Numerals that do not fall under another type
# Texas : GPE - Countries, cities, states
# Febr : PERSON - People, including fictional
# 40 : CARDINAL - Numerals that do not fall under another type
# Jan 13, 2023 : DATE - Absolute or relative dates or periods
# 41 : CARDINAL - Numerals that do not fall under another type
# Jan 13, 2021 : DATE - Absolute or relative dates or periods
# Minnes : PERSON - People, including fictional
# 42 : CARDINAL - Numerals that do not fall under another type
# Jan 15, 2022 : DATE - Absolute or relative dates or periods
# 43 : CARDINAL - Numerals that do not fall under another type
# 44 : CARDINAL - Numerals that do not fall under another type
# 2023 : DATE - Absolute or relative dates or periods
# 45 : CARDINAL - Numerals that do not fall under another type
# 7, 2023 : DATE - Absolute or relative dates or periods
# March : DATE - Absolute or relative dates or periods
# 46 : CARDINAL - Numerals that do not fall under another type
# 15, 2022 : DATE - Absolute or relative dates or periods
# 47 : CARDINAL - Numerals that do not fall under another type
# Late-winter : DATE - Absolute or relative dates or periods
# 48 : CARDINAL - Numerals that do not fall under another type
# 49 : CARDINAL - Numerals that do not fall under another type
# 14, 2021 : DATE - Absolute or relative dates or periods
# late winter : DATE - Absolute or relative dates or periods
# 50 : CARDINAL - Numerals that do not fall under another type
# 51 : CARDINAL - Numerals that do not fall under another type
# Jan 17, 2019 : DATE - Absolute or relative dates or periods
# 52 : CARDINAL - Numerals that do not fall under another type
# 53 : CARDINAL - Numerals that do not fall under another type
# a Winter Storm : ORG - Companies, agencies, institutions, etc.
# 54 : CARDINAL - Numerals that do not fall under another type
# Two : CARDINAL - Numerals that do not fall under another type
# Blizzard : PERSON - People, including fictional
# 55 : CARDINAL - Numerals that do not fall under another type
# WALTHAM : GPE - Countries, cities, states
# MA : GPE - Countries, cities, states
# 56 : CARDINAL - Numerals that do not fall under another type
# March 24, 2023 : DATE - Absolute or relative dates or periods
# 57 : CARDINAL - Numerals that do not fall under another type
# Winter : PERSON - People, including fictional
# 58 : CARDINAL - Numerals that do not fall under another type
# 59 : CARDINAL - Numerals that do not fall under another type
# Jan 29, 2023 : DATE - Absolute or relative dates or periods
# 60 : CARDINAL - Numerals that do not fall under another type
# winter : DATE - Absolute or relative dates or periods
# 61 : CARDINAL - Numerals that do not fall under another type
# 22, 2022 : DATE - Absolute or relative dates or periods
# Kansas : GPE - Countries, cities, states
# 62 : CARDINAL - Numerals that do not fall under another type
# 19, 2022 : DATE - Absolute or relative dates or periods
# the first day of winter : DATE - Absolute or relative dates or periods
# 63 : CARDINAL - Numerals that do not fall under another type
# 8, 2023 : DATE - Absolute or relative dates or periods
# Watertown : GPE - Countries, cities, states
# New York : GPE - Countries, cities, states
# Pharma : PERSON - People, including fictional
# 64 : CARDINAL - Numerals that do not fall under another type
# 65 : CARDINAL - Numerals that do not fall under another type
# Early winter : DATE - Absolute or relative dates or periods
# Illinoi : GPE - Countries, cities, states
# 66 : CARDINAL - Numerals that do not fall under another type
# Winter : DATE - Absolute or relative dates or periods
# 67 : CARDINAL - Numerals that do not fall under another type
# 25 : CARDINAL - Numerals that do not fall under another type
# 68 : CARDINAL - Numerals that do not fall under another type
# May 23, 2023 : DATE - Absolute or relative dates or periods
# 69 : CARDINAL - Numerals that do not fall under another type
# U.S. : GPE - Countries, cities, states
# 70 : CARDINAL - Numerals that do not fall under another type
# 71 : CARDINAL - Numerals that do not fall under another type
# 72 : CARDINAL - Numerals that do not fall under another type
# 73 : CARDINAL - Numerals that do not fall under another type
# 8, 2021 : DATE - Absolute or relative dates or periods
# 74 : CARDINAL - Numerals that do not fall under another type
# 75 : CARDINAL - Numerals that do not fall under another type
# Minnesota : GPE - Countries, cities, states
# Freezing Winter : PERSON - People, including fictional
# 76 : CARDINAL - Numerals that do not fall under another type
# Late winter : DATE - Absolute or relative dates or periods
# South : LOC - Non-GPE locations, mountain ranges, bodies of water
# 77 : CARDINAL - Numerals that do not fall under another type
# 78 : CARDINAL - Numerals that do not fall under another type
# May 23, 2023 : DATE - Absolute or relative dates or periods
# Houston : GPE - Countries, cities, states
# 79 : CARDINAL - Numerals that do not fall under another type
# 80 : CARDINAL - Numerals that do not fall under another type
# Jan 16, 2022 : DATE - Absolute or relative dates or periods
# Buffalo : GPE - Countries, cities, states
# 81 : CARDINAL - Numerals that do not fall under another type
# 82 : CARDINAL - Numerals that do not fall under another type
# 20, 2009 : DATE - Absolute or relative dates or periods
# Spider Butte : PERSON - People, including fictional
# a day : DATE - Absolute or relative dates or periods
# 83 : CARDINAL - Numerals that do not fall under another type
# 311 : CARDINAL - Numerals that do not fall under another type
# CRM : PRODUCT - Objects, vehicles, foods, etc. (not services)
# 84 : CARDINAL - Numerals that do not fall under another type
# 2017 : DATE - Absolute or relative dates or periods
# 85 : CARDINAL - Numerals that do not fall under another type
# SMU : ORG - Companies, agencies, institutions, etc.
# Dallas : GPE - Countries, cities, states
# 86 : CARDINAL - Numerals that do not fall under another type
# Jan 17, 2022 : DATE - Absolute or relative dates or periods
# 87 : CARDINAL - Numerals that do not fall under another type
# Jan 4, 2022 : DATE - Absolute or relative dates or periods
# 88 : CARDINAL - Numerals that do not fall under another type
# The National Weather Service : ORG - Companies, agencies, institutions, etc.
# 89 : CARDINAL - Numerals that do not fall under another type
# 24, 2022 : DATE - Absolute or relative dates or periods
# 416 : CARDINAL - Numerals that do not fall under another type
# 287 : CARDINAL - Numerals that do not fall under another type
# 833 : CARDINAL - Numerals that do not fall under another type
# 90 : CARDINAL - Numerals that do not fall under another type
# 7, 2018 : DATE - Absolute or relative dates or periods
# Third : ORDINAL - "first", "second", etc.
# 91 : CARDINAL - Numerals that do not fall under another type
# Winter : DATE - Absolute or relative dates or periods
# 92 : CARDINAL - Numerals that do not fall under another type
# 2017 : DATE - Absolute or relative dates or periods
# 93 : CARDINAL - Numerals that do not fall under another type
# SMU : ORG - Companies, agencies, institutions, etc.
# Dallas : GPE - Countries, cities, states
# 94 : CARDINAL - Numerals that do not fall under another type
# Jan 17, 2022 : DATE - Absolute or relative dates or periods
# 95 : CARDINAL - Numerals that do not fall under another type
# Jan 4, 2022 : DATE - Absolute or relative dates or periods
# 96 : CARDINAL - Numerals that do not fall under another type
# The National Weather Service : ORG - Companies, agencies, institutions, etc.
# 97 : CARDINAL - Numerals that do not fall under another type
# 24, 2022 : DATE - Absolute or relative dates or periods
# 416 : CARDINAL - Numerals that do not fall under another type
# 287 : CARDINAL - Numerals that do not fall under another type
# 833 : CARDINAL - Numerals that do not fall under another type
# 98 : CARDINAL - Numerals that do not fall under another type
# 7, 2018 : DATE - Absolute or relative dates or periods
# Third : ORDINAL - "first", "second", etc.
# 99 : CARDINAL - Numerals that do not fall under another type
# Winter : DATE - Absolute or relative dates or periods
# 100 : CARDINAL - Numerals that do not fall under another type

# %% [markdown]
# Looking at the results, we can see how the NER system classified entitites.
